# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow	import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import r2_score

# %%
# load admissions data
admissions_data = pd.read_csv("admissions_data.csv")
#print(admissions_data.head())


# mark predicted values
labels = admissions_data.iloc[:,-1]

# mark features
features = admissions_data.iloc[:, 1:8]

#split our training and test set
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size=0.25, random_state = 42)

# standardizing our data by scaling it
sc = StandardScaler()
features_train_scale = sc.fit_transform(features_train)
features_test_scale = sc.transform(features_test)



# function to design the model
def design_model(feature_data):
	model = Sequential()
	num_features = feature_data.shape[1]
	input = tf.keras.Input(shape=(num_features))
	model.add(input)
	# this model has two hidden layers and two dropout layers
	# relu activation function is used at both hidden layers
	hidden_layer = layers.Dense(16, activation='relu')
	model.add(hidden_layer)
	model.add(layers.Dropout(0.1))
	hidden_layer_2 = layers.Dense(8, activation='relu')
	model.add(hidden_layer_2)
	model.add(layers.Dropout(0.2))
	model.add(layers.Dense(1))

	# using an adam optimizer with a learning rate of 0.005
	# using mean-squared error as our loss function and mean average error as our metric
	opt = keras.optimizers.Adam(learning_rate=0.005)
	model.compile(loss='mse', metrics=['mae'], optimizer=opt)
	return model


# apply the model to the scaled training data
model = design_model(features_train_scale)


# apply early stopping for efficiency
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# fit the model with 100 epochs and a batch size of 8
# validation split at 0.25
history = model.fit(features_train_scale, labels_train.to_numpy(), epochs=100, batch_size=8, verbose=1, validation_split=0.25, callbacks=[es])

# evaluate the model
val_mse, val_mae = model.evaluate(features_test_scale, labels_test.to_numpy(), verbose = 0)

# view the MAE performance
print("MAE: ", val_mae)

# evauate r-squared score
y_pred = model.predict(features_test_scale)

print(r2_score(labels_test,y_pred))

# plot MAE and val_MAE over each epoch
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(history.history['mae'])
ax1.plot(history.history['val_mae'])
ax1.set_title('model mae')
ax1.set_ylabel('MAE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'validation'], loc='upper left')

# Plot loss and val_loss over each epoch
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title('model loss')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/100
# 36/36 [==============================] - 3s 23ms/step - loss: 0.8088 - mae: 0.6011 - val_loss: 0.0872 - val_mae: 0.2371
# Epoch 2/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.1440 - mae: 0.3201 - val_loss: 0.0543 - val_mae: 0.2003
# Epoch 3/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0824 - mae: 0.2331 - val_loss: 0.0351 - val_mae: 0.1563
# Epoch 4/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0865 - mae: 0.2380 - val_loss: 0.0164 - val_mae: 0.1050
# Epoch 5/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0472 - mae: 0.1694 - val_loss: 0.0109 - val_mae: 0.0815
# Epoch 6/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0438 - mae: 0.1645 - val_loss: 0.0156 - val_mae: 0.1097
# Epoch 7/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0308 - mae: 0.1358 - val_loss: 0.0092 - val_mae: 0.0771
# Epoch 8/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0292 - mae: 0.1367 - val_loss: 0.0077 - val_mae: 0.0670
# Epoch 9/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0225 - mae: 0.1189 - val_loss: 0.0074 - val_mae: 0.0672
# Epoch 10/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0237 - mae: 0.1182 - val_loss: 0.0083 - val_mae: 0.0729
# Epoch 11/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0175 - mae: 0.1069 - val_loss: 0.0076 - val_mae: 0.0702
# Epoch 12/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0158 - mae: 0.1005 - val_loss: 0.0060 - val_mae: 0.0603
# Epoch 13/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0169 - mae: 0.1029 - val_loss: 0.0071 - val_mae: 0.0691
# Epoch 14/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0125 - mae: 0.0879 - val_loss: 0.0057 - val_mae: 0.0604
# Epoch 15/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0114 - mae: 0.0838 - val_loss: 0.0051 - val_mae: 0.0554
# Epoch 16/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0112 - mae: 0.0856 - val_loss: 0.0052 - val_mae: 0.0587
# Epoch 17/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0715 - val_loss: 0.0053 - val_mae: 0.0592
# Epoch 18/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0098 - mae: 0.0744 - val_loss: 0.0049 - val_mae: 0.0565
# Epoch 19/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0069 - mae: 0.0630 - val_loss: 0.0046 - val_mae: 0.0546
# Epoch 20/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0087 - mae: 0.0712 - val_loss: 0.0044 - val_mae: 0.0536
# Epoch 21/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0106 - mae: 0.0793 - val_loss: 0.0038 - val_mae: 0.0472
# Epoch 22/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0067 - mae: 0.0654 - val_loss: 0.0045 - val_mae: 0.0554
# Epoch 23/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0062 - mae: 0.0619 - val_loss: 0.0041 - val_mae: 0.0520
# Epoch 24/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0089 - mae: 0.0753 - val_loss: 0.0039 - val_mae: 0.0494
# Epoch 25/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0074 - mae: 0.0686 - val_loss: 0.0050 - val_mae: 0.0590
# Epoch 26/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0680 - val_loss: 0.0049 - val_mae: 0.0588
# Epoch 27/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0034 - val_mae: 0.0458
# Epoch 28/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0653 - val_loss: 0.0039 - val_mae: 0.0510
# Epoch 29/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0070 - mae: 0.0642 - val_loss: 0.0035 - val_mae: 0.0468
# Epoch 30/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0547 - val_loss: 0.0043 - val_mae: 0.0551
# Epoch 31/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0066 - mae: 0.0629 - val_loss: 0.0035 - val_mae: 0.0475
# Epoch 32/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0066 - mae: 0.0611 - val_loss: 0.0033 - val_mae: 0.0459
# Epoch 33/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0573 - val_loss: 0.0041 - val_mae: 0.0536
# Epoch 34/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0064 - mae: 0.0616 - val_loss: 0.0034 - val_mae: 0.0463
# Epoch 35/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0072 - mae: 0.0663 - val_loss: 0.0035 - val_mae: 0.0484
# Epoch 36/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0068 - mae: 0.0614 - val_loss: 0.0039 - val_mae: 0.0518
# Epoch 37/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0558 - val_loss: 0.0035 - val_mae: 0.0484
# Epoch 38/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0059 - mae: 0.0582 - val_loss: 0.0030 - val_mae: 0.0437
# Epoch 39/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0045 - mae: 0.0515 - val_loss: 0.0040 - val_mae: 0.0539
# Epoch 40/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0071 - mae: 0.0637 - val_loss: 0.0035 - val_mae: 0.0475
# Epoch 41/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0071 - mae: 0.0636 - val_loss: 0.0040 - val_mae: 0.0517
# Epoch 42/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0075 - mae: 0.0652 - val_loss: 0.0033 - val_mae: 0.0455
# Epoch 43/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0058 - mae: 0.0607 - val_loss: 0.0031 - val_mae: 0.0427
# Epoch 44/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0064 - mae: 0.0600 - val_loss: 0.0036 - val_mae: 0.0489
# Epoch 45/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0056 - mae: 0.0579 - val_loss: 0.0033 - val_mae: 0.0470
# Epoch 46/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0553 - val_loss: 0.0041 - val_mae: 0.0538
# Epoch 47/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0631 - val_loss: 0.0030 - val_mae: 0.0420
# Epoch 48/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0055 - mae: 0.0558 - val_loss: 0.0033 - val_mae: 0.0437
# Epoch 49/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0056 - mae: 0.0562 - val_loss: 0.0032 - val_mae: 0.0458
# Epoch 50/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0054 - mae: 0.0556 - val_loss: 0.0033 - val_mae: 0.0452
# Epoch 51/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0067 - mae: 0.0638 - val_loss: 0.0030 - val_mae: 0.0430
# Epoch 52/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0066 - mae: 0.0627 - val_loss: 0.0031 - val_mae: 0.0451
# Epoch 53/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0056 - mae: 0.0573 - val_loss: 0.0031 - val_mae: 0.0425
# Epoch 54/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0051 - mae: 0.0530 - val_loss: 0.0039 - val_mae: 0.0530
# Epoch 55/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0054 - mae: 0.0552 - val_loss: 0.0037 - val_mae: 0.0509
# Epoch 56/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0056 - mae: 0.0593 - val_loss: 0.0034 - val_mae: 0.0462
# Epoch 57/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0065 - mae: 0.0640 - val_loss: 0.0029 - val_mae: 0.0414
# Epoch 58/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0541 - val_loss: 0.0032 - val_mae: 0.0447
# Epoch 59/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0029 - val_mae: 0.0391
# Epoch 60/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0051 - mae: 0.0542 - val_loss: 0.0035 - val_mae: 0.0459
# Epoch 61/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0555 - val_loss: 0.0032 - val_mae: 0.0459
# Epoch 62/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0067 - mae: 0.0630 - val_loss: 0.0038 - val_mae: 0.0493
# Epoch 63/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0054 - mae: 0.0543 - val_loss: 0.0030 - val_mae: 0.0402
# Epoch 64/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0541 - val_loss: 0.0031 - val_mae: 0.0443
# Epoch 65/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0049 - mae: 0.0539 - val_loss: 0.0033 - val_mae: 0.0467
# Epoch 66/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0613 - val_loss: 0.0031 - val_mae: 0.0397
# Epoch 67/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0049 - mae: 0.0522 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 68/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0060 - mae: 0.0592 - val_loss: 0.0034 - val_mae: 0.0470
# Epoch 69/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0053 - mae: 0.0543 - val_loss: 0.0030 - val_mae: 0.0429
# Epoch 70/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0062 - mae: 0.0620 - val_loss: 0.0032 - val_mae: 0.0447
# Epoch 71/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0056 - mae: 0.0584 - val_loss: 0.0033 - val_mae: 0.0431
# Epoch 72/100
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0053 - mae: 0.0562 - val_loss: 0.0038 - val_mae: 0.0516
# Epoch 73/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0051 - mae: 0.0567 - val_loss: 0.0028 - val_mae: 0.0382
# Epoch 74/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0066 - mae: 0.0614 - val_loss: 0.0037 - val_mae: 0.0498
# Epoch 75/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0060 - mae: 0.0571 - val_loss: 0.0036 - val_mae: 0.0494
# Epoch 76/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0065 - mae: 0.0608 - val_loss: 0.0037 - val_mae: 0.0478
# Epoch 77/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0054 - mae: 0.0559 - val_loss: 0.0029 - val_mae: 0.0413
# Epoch 78/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0591 - val_loss: 0.0032 - val_mae: 0.0455
# Epoch 79/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0051 - mae: 0.0545 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 80/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0046 - mae: 0.0517 - val_loss: 0.0031 - val_mae: 0.0433
# Epoch 81/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0565 - val_loss: 0.0028 - val_mae: 0.0416
# Epoch 82/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0571 - val_loss: 0.0038 - val_mae: 0.0501
# Epoch 83/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0052 - mae: 0.0511 - val_loss: 0.0027 - val_mae: 0.0394
# Epoch 84/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0060 - mae: 0.0595 - val_loss: 0.0029 - val_mae: 0.0427
# Epoch 85/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0048 - mae: 0.0541 - val_loss: 0.0030 - val_mae: 0.0424
# Epoch 86/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0049 - mae: 0.0531 - val_loss: 0.0032 - val_mae: 0.0448
# Epoch 87/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0069 - mae: 0.0657 - val_loss: 0.0033 - val_mae: 0.0423
# Epoch 88/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0055 - mae: 0.0574 - val_loss: 0.0031 - val_mae: 0.0435
# Epoch 89/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0048 - mae: 0.0543 - val_loss: 0.0029 - val_mae: 0.0426
# Epoch 90/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0057 - mae: 0.0567 - val_loss: 0.0031 - val_mae: 0.0400
# Epoch 91/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0541 - val_loss: 0.0032 - val_mae: 0.0441
# Epoch 92/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0058 - mae: 0.0584 - val_loss: 0.0032 - val_mae: 0.0435
# Epoch 93/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0059 - mae: 0.0588 - val_loss: 0.0042 - val_mae: 0.0545
# Epoch 94/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0058 - mae: 0.0583 - val_loss: 0.0026 - val_mae: 0.0384
# Epoch 95/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0050 - mae: 0.0554 - val_loss: 0.0028 - val_mae: 0.0422
# Epoch 96/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0043 - mae: 0.0495 - val_loss: 0.0032 - val_mae: 0.0465
# Epoch 97/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0049 - mae: 0.0529 - val_loss: 0.0030 - val_mae: 0.0414
# Epoch 98/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0054 - mae: 0.0562 - val_loss: 0.0030 - val_mae: 0.0415
# Epoch 99/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0049 - mae: 0.0516 - val_loss: 0.0035 - val_mae: 0.0492
# Epoch 100/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0057 - mae: 0.0574 - val_loss: 0.0034 - val_mae: 0.0426
# MAE:  0.042997147887945175
# 0.8097341687806638
